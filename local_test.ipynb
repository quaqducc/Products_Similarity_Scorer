# %%
import os

print(os.path.exists("spsc_data/spsc_data/spsc_tree.json"))
# Out:
# True

# %%
from product_similarity.spsc import retrieve_spsc_contexts
print(retrieve_spsc_contexts("live chickens", "live ducks", top_k=3))
# Kỳ vọng có các dòng dạng: "SPSC 10101601: Live chickens", "Path: ... > Birds and fowl > Live chickens"
# Out:
# ['SPSC 10101601: Live chickens\nPath: Raw Materials, Chemicals, Paper, Fuel > Live Plant and Animal Material and Accessories and Supplies > Live animals > Birds and fowl > Live chickens', 'SPSC 10101602: Live ducks\nPath: Raw Materials, Chemicals, Paper, Fuel > Live Plant and Animal Material and Accessories and Supplies > Live animals > Birds and fowl > Live ducks', 'SPSC 10101701: Live salmon\nPath: Raw Materials, Chemicals, Paper, Fuel > Live Plant and Animal Material and Accessories and Supplies > Live animals > Live fish > Live salmon']

# %%
# Test with the provided case and print full prompt
from product_similarity.pipeline import run_similarity

p1 = "Chemicals"
p2 = "chemical additives for detergents"

res = run_similarity(
	p1,
	p2,
	class_1=1,
	class_2=1,
	max_fewshot=2,
	top_k=2,
	include_spsc=True,
	spsc_top_k=2,
	model_name=None,
)

print("\n".join(["=== CONTEXTS ===", *res["contexts"], "\n=== PROMPT ===", res["prompt"]]))
# Out:
# === CONTEXTS ===
# Class 1: Chemicals for use in industry, science and photography, as well as in agriculture, horticulture and forestry; unprocessed artificial resins, unprocessed plastics; fire extinguishing and fire prevention compositions; tempering and soldering preparations; substances for tanning animal skins and hides; adhesives for use in industry; putties and other paste fillers; compost, manures, fertilizers; biological preparations for use in industry and science
# Examples: combusting preparations [chemical additives to motor fuel]; adhesives for industrial purposes; salt for preserving, other than for foodstuffs
# SPSC 12165100: Chemicals for enhanced oil recovery
# Path: Raw Materials, Chemicals, Paper, Fuel > Chemicals including Bio Chemicals and Gas Materials > Additives > Chemicals for enhanced oil recovery
# SPSC 12000000: Chemicals including Bio Chemicals and Gas Materials
# Path: Raw Materials, Chemicals, Paper, Fuel > Chemicals including Bio Chemicals and Gas Materials
#
# === PROMPT ===
# You are an expert examiner in trademark classification (NICE system).
# Your task is to assess ONLY the similarity in NATURE between two goods or services.
# Nature refers to what the product essentially is (its type, composition, materials, technical category).
#
# === EVALUATION PROCESS (Nature only) ===
# • Identify what each product essentially is (chemical, device, material, etc.).
# • Check if they belong to the same technical category or share similar materials/composition.
# • Ignore intended purpose and other factors unless strictly necessary to clarify nature.
#
# === SCORING SCALE ===
# Use whole numbers only:
# 0 = Not similar
# 1 = Slightly similar
# 2 = Moderately similar
# 3 = Similar
# 4 = Highly similar / identical
#
# Keep your reasoning concise and factual (max 3–5 sentences per case).
# Your final answer must include 'Reasoning' and 'Output' sections, matching the format of the examples.
#
# ### Example USECASE_SCORE_0
# **Input:**
# - Product 1: Chemicals used in industry (Class 1)
# - Product 2: Scientific and technological services, research and design (Class 42)
# - Class Info: {
#   "class_1": "Mainly chemical products for use in industry, science and agriculture.",
#   "class_42": "Mainly services provided by persons in relation to the theoretical and practical aspects of complex fields of activities."
# }
#
# **Reasoning:**
# - Nature: There is a fundamental difference between a physical product (chemicals) and an intangible service (research services). Their nature is completely different.
# - Intended_purpose: The purpose of industrial chemicals is to be used as raw materials or processing aids. The purpose of scientific services is to provide knowledge and solutions. These purposes do not overlap.
# - Channels_of_trade: Chemicals are sold through B2B supply chains for goods. Scientific services are contracted through professional service agreements. The channels are not similar.
#
# **Output:**
# - Nature Score: 0
#
#
# ### Example USECASE_SCORE_1
# **Input:**
# - Product 1: Adhesives for industrial purposes (Class 1)
# - Product 2: Research and development of new products for others (Class 42)
# - Class Info: {
#   "class_1": "Mainly chemical products for use in industry, science and agriculture.",
#   "class_42": "Mainly services provided by persons in relation to the theoretical and practical aspects of complex fields of activities."
# }
#
# **Reasoning:**
# - Nature: The nature is entirely different: one is a physical product (adhesives), the other is an intangible service (R&D).
# - Intended_purpose: There is a slight connection in purpose, as adhesives (product) might be used during the process of research and development (service). The relationship is indirect.
# - Channels_of_trade: The channels are different. Industrial adhesives are sold via material suppliers, while R&D services are procured via service contracts with research firms or institutions.
#
# **Output:**
# - Nature Score: 0
#
#
# ### Reference Context (from NICE classification & Guidelines):
# Class 1: Chemicals for use in industry, science and photography, as well as in agriculture, horticulture and forestry; unprocessed artificial resins, unprocessed plastics; fire extinguishing and fire prevention compositions; tempering and soldering preparations; substances for tanning animal skins and hides; adhesives for use in industry; putties and other paste fillers; compost, manures, fertilizers; biological preparations for use in industry and science
# Examples: combusting preparations [chemical additives to motor fuel]; adhesives for industrial purposes; salt for preserving, other than for foodstuffs
# SPSC 12165100: Chemicals for enhanced oil recovery
# Path: Raw Materials, Chemicals, Paper, Fuel > Chemicals including Bio Chemicals and Gas Materials > Additives > Chemicals for enhanced oil recovery
# SPSC 12000000: Chemicals including Bio Chemicals and Gas Materials
# Path: Raw Materials, Chemicals, Paper, Fuel > Chemicals including Bio Chemicals and Gas Materials
#
# ### New Case
# - Product 1: Chemicals
# - Product 2: chemical additives for detergents
#
# Please reason step-by-step focusing ONLY on the Nature factor.
# Then provide your conclusion following this format:
#
# Reasoning:
# - Nature: (brief reasoning)
#
# Output:
# - Nature Score: [0–4]
# Your final line must clearly show the Nature Score.
